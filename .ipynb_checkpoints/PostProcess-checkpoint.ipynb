# %%
import re
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# ============================================================
# Put your full run folder path here
# ============================================================

RUN_DIR = Path("../work/experiments/shabdiz/latest_4node_run")

# Choose latency metric: "avg_latency_ms", "p50_latency_ms", "p99_latency_ms", "p999_latency_ms"
LATENCY_COL = "avg_latency_ms"


# ============================================================
# Regex for [CLIENT_SEC] lines
# ============================================================

client_sec_pattern = re.compile(
    r"\[CLIENT_SEC\]\s+"
    r"sec=(?P<sec>\d+)\s+"
    r"requests=(?P<requests>\d+)\s+"
    r"throughput=(?P<throughput>[0-9.]+)\s+"
    r"avg_latency_ms=(?P<avg_latency_ms>[0-9.]+|nan)\s+"
    r"p50_latency_ms=(?P<p50_latency_ms>[0-9.]+|nan)\s+"
    r"p99_latency_ms=(?P<p99_latency_ms>[0-9.]+|nan)"
    r"(?:\s+p999_latency_ms=(?P<p999_latency_ms>[0-9.]+|nan))?"
)


def parse_float_or_nan(x):
    if x is None or x == "nan":
        return np.nan
    return float(x)


def parse_client_log(log_file, client_id):
    rows = []

    with open(log_file, errors="ignore") as f:
        for line in f:
            m = client_sec_pattern.search(line)
            if not m:
                continue

            rows.append({
                "client_id": client_id,
                "sec": int(m.group("sec")),
                "requests": int(m.group("requests")),
                "throughput_tps": float(m.group("throughput")),
                "avg_latency_ms": parse_float_or_nan(m.group("avg_latency_ms")),
                "p50_latency_ms": parse_float_or_nan(m.group("p50_latency_ms")),
                "p99_latency_ms": parse_float_or_nan(m.group("p99_latency_ms")),
                "p999_latency_ms": parse_float_or_nan(m.group("p999_latency_ms")),
            })

    return pd.DataFrame(rows)


def weighted_mean(values, weights):
    values = np.asarray(values, dtype=float)
    weights = np.asarray(weights, dtype=float)

    valid = ~np.isnan(values)
    if valid.sum() == 0:
        return np.nan

    values = values[valid]
    weights = weights[valid]

    if weights.sum() <= 0:
        return np.nan

    return np.average(values, weights=weights)


def aggregate_clients_by_second(df):
    rows = []

    for sec, g in df.groupby("sec"):
        total_requests = int(g["requests"].sum())

        rows.append({
            "sec": sec,
            "requests": total_requests,
            "throughput_tps": float(g["throughput_tps"].sum()),
            "avg_latency_ms": weighted_mean(g["avg_latency_ms"], g["requests"]),
            "p50_latency_ms": weighted_mean(g["p50_latency_ms"], g["requests"]),
            "p99_latency_ms": weighted_mean(g["p99_latency_ms"], g["requests"]),
            "p999_latency_ms": weighted_mean(g["p999_latency_ms"], g["requests"]),
        })

    return pd.DataFrame(rows).sort_values("sec")


# ============================================================
# Load logs
# ============================================================

client_logs = sorted(RUN_DIR.glob("client_*.log"))

if not client_logs:
    old_log = RUN_DIR / "client.log"
    if old_log.exists():
        client_logs = [old_log]

if not client_logs:
    raise FileNotFoundError(f"No client_*.log or client.log found in {RUN_DIR}")

client_dfs = []

for i, log_file in enumerate(client_logs):
    print(f"Parsing {log_file}")
    df = parse_client_log(log_file, client_id=i)

    if df.empty:
        print(f"WARNING: no [CLIENT_SEC] lines found in {log_file}")
    else:
        client_dfs.append(df)

if not client_dfs:
    raise RuntimeError("No [CLIENT_SEC] lines found in any client log.")

raw_df = pd.concat(client_dfs, ignore_index=True)
agg_df = aggregate_clients_by_second(raw_df)

# Remove zero-request seconds for cleaner plots.
plot_df = agg_df[agg_df["requests"] > 0].copy()

# print(plot_df[[
#     "sec",
#     "requests",
#     "throughput_tps",
#     "avg_latency_ms",
#     "p50_latency_ms",
#     "p99_latency_ms",
#     "p999_latency_ms",
# ]].to_string(index=False))


# ============================================================
# Plot 1: Throughput vs time
# ============================================================

plt.figure(figsize=(8, 4.5))
plt.plot(
    plot_df["sec"],
    plot_df["throughput_tps"],
    marker="o",
    linewidth=2,
)
plt.xlabel("Time (s)")
plt.ylabel("Throughput (requests/s)")
plt.title("Throughput vs Time")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()


# ============================================================
# Plot 2: Latency vs time
# ============================================================

plt.figure(figsize=(8, 4.5))
plt.plot(
    plot_df["sec"],
    plot_df[LATENCY_COL],
    marker="o",
    linewidth=2,
)
plt.xlabel("Time (s)")
plt.ylabel("Latency (ms)")
plt.title(f"{LATENCY_COL} vs Time")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Parsing ../work/experiments/shabdiz/latest_4node_run/client_0.log
